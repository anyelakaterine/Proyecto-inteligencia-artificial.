# %% [markdown]
# <a href="https://colab.research.google.com/github/anyelakaterine/Proyecto-inteligencia-artificial./blob/main/TP/TEOR%C3%8DA%20DE%20JUEGOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================================
# NOMBRE DEL CÓDIGO:
# DILEMA DEL PRISIONERO
# ==========================================================

import random

opciones = ["Cooperar","Traicionar"]

jugador1 = random.choice(opciones)
jugador2 = random.choice(opciones)

print("Jugador 1:",jugador1)
print("Jugador 2:",jugador2)

# ==========================================================
# NOMBRE DEL CÓDIGO:
# JUEGO PIEDRA PAPEL TIJERA
# ==========================================================

import random

opciones = ["piedra","papel","tijera"]

jugador = random.choice(opciones)
computador = random.choice(opciones)

print("Jugador:",jugador)
print("Computador:",computador)

# ==========================================================
# NOMBRE DEL CÓDIGO:
# ESTRATEGIA DE PRECIOS ENTRE EMPRESAS
# ==========================================================

empresa1 = "precio alto"
empresa2 = "precio bajo"

print("Empresa 1:",empresa1)
print("Empresa 2:",empresa2)
# Out:
# Jugador 1: Cooperar
# Jugador 2: Cooperar
# Jugador: tijera
# Computador: piedra
# Empresa 1: precio alto
# Empresa 2: precio bajo
